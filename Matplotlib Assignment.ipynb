# %% [markdown]
# ### Q1. What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Matplotlib is library which is used for visualisation, Five plots that can be plotted using the Pyplot module of Matplotlib.
# 1. Line Plot
# 2. Bar Plot
# 3. Histogram
# 4. ScatterPlot
# 5. Pie Chart

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
import numpy as np
np.random.seed(3)
x=3+np.random.normal(0,2,50)
y=3+np.random.normal(0,2,len(x))

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.xlabel("this is my x data")
plt.ylabel("this is my y data")
plt.title("this is my title")
# Out:
# Text(0.5, 1.0, 'this is my title')

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:

# %%
#With the subplot() function you can draw multiple plots in one figure
x=np.array([0,1,2,3,4,5])
y= np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2,2,1)
plt.plot(x,y)

x=np.array([0,1,2,3,4,5])
y= np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2,2,2)
plt.plot(x,y)

x=np.array([0,1,2,3,4,5])
y= np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2,2,3)
plt.plot(x,y)

x=np.array([0,1,2,3,4,5])
y=np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,2,4)
plt.plot(x,y)

# %% [markdown]
# ### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# Bar plot is used for ploting categorical data along with their frquency

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# Box plot is one of the method of data visualisation it used to detect outliers and understand the distribution of data

# %%
box1 = [np.random.normal(100, 10, 200),np.random.normal(90, 20, 200)]

# %%
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e4cc295af0>,
#   <matplotlib.lines.Line2D at 0x1e4cc295d90>,
#   <matplotlib.lines.Line2D at 0x1e4cc2a5dc0>,
#   <matplotlib.lines.Line2D at 0x1e4cc2b40a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e4cc2a5070>,
#   <matplotlib.lines.Line2D at 0x1e4cc2a5310>,
#   <matplotlib.lines.Line2D at 0x1e4cc2b4340>,
#   <matplotlib.lines.Line2D at 0x1e4cc2b4430>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e4cc295850>,
#   <matplotlib.lines.Line2D at 0x1e4cc2a5b20>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e4cc2a55b0>,
#   <matplotlib.lines.Line2D at 0x1e4cc2b46d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e4cc2a5850>,
#   <matplotlib.lines.Line2D at 0x1e4cc2b4970>],
#  'means': []}
